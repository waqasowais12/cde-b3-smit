# %%
import pandas as pd

# %%
bricks = {"country": ['Brazil', 'Russia', 'India', 'China', 'South Africa'],
         "capital": ['Brazilia', 'Moscow', 'New Delhi', 'Beijing', 'Pretoria'],
         "area": [8.516, 17.100, 3.286, 9.597, 1.221],
         "population": [200.40, 143.50, 1252.00, 1357.00, 52.98]}

# %%
bricks_df = pd.DataFrame(bricks)

# %%
bricks_df
# Out:
#         country    capital    area  population
# 0        Brazil   Brazilia   8.516      200.40
# 1        Russia     Moscow  17.100      143.50
# 2         India  New Delhi   3.286     1252.00
# 3         China    Beijing   9.597     1357.00
# 4  South Africa   Pretoria   1.221       52.98

# %%
# bricks_df.index = ['BR', 'RU', 'IN', 'CH', 'SU']

# %%
bricks_df
# Out:
#         country    capital    area  population
# 0        Brazil   Brazilia   8.516      200.40
# 1        Russia     Moscow  17.100      143.50
# 2         India  New Delhi   3.286     1252.00
# 3         China    Beijing   9.597     1357.00
# 4  South Africa   Pretoria   1.221       52.98

# %%
bricks_csv = pd.read_csv('./dataset/bricks.csv', index_col=0)

# %%
bricks_csv
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
bricks_csv['country', 'capital']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('country', 'capital')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 bricks_csv['country', 'capital']
#
# ...

# %%
bricks_csv[['country', 'capital']]
# Out:
#          country    capital
# BR        Brazil   Brasilia
# RU        Russia     Moscow
# IN         India  New Delhi
# CH         China    Beijing
# SA  South Africa   Pretoria

# %%
bricks_csv[1:4]
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %%
bricks_csv[2:]
# Out:
#          country    capital   area  population
# IN         India  New Delhi  3.286     1252.00
# CH         China    Beijing  9.597     1357.00
# SA  South Africa   Pretoria  1.221       52.98

# %%
bricks_csv.loc['IN']
# Out:
# country           India
# capital       New Delhi
# area              3.286
# population       1252.0
# Name: IN, dtype: object

# %%
print(type(bricks_csv.loc['IN']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
bricks_csv.loc[['IN']]
# Out:
#    country    capital   area  population
# IN   India  New Delhi  3.286      1252.0

# %%
bricks_csv.loc[['IN', 'SA']]
# Out:
#          country    capital   area  population
# IN         India  New Delhi  3.286     1252.00
# SA  South Africa   Pretoria  1.221       52.98

# %%
bricks_csv.loc[['IN', 'SA'], ['country', 'capital']]
# Out:
#          country    capital
# IN         India  New Delhi
# SA  South Africa   Pretoria

# %%
bricks_csv.iloc[[2, 3]]
# Out:
#    country    capital   area  population
# IN   India  New Delhi  3.286      1252.0
# CH   China    Beijing  9.597      1357.0

# %%
bricks_csv.iloc[[3], [3]]
# Out:
#     population
# CH      1357.0

# %%
bricks_csv.loc[:,[ 'country']]
# Out:
#          country
# BR        Brazil
# RU        Russia
# IN         India
# CH         China
# SA  South Africa

# %%
bricks_csv.iloc[[1]]
# Out:
#    country capital  area  population
# RU  Russia  Moscow  17.1       143.5

# %%
bricks_csv.iloc[[1,2,3]]
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %%
bricks_csv.iloc[[1,2,3], 2:4]
# Out:
#       area  population
# RU  17.100       143.5
# IN   3.286      1252.0
# CH   9.597      1357.0

# %%
bricks_csv.iloc[[1,2,3], [0,2,3]]
# Out:
#    country    area  population
# RU  Russia  17.100       143.5
# IN   India   3.286      1252.0
# CH   China   9.597      1357.0

# %%
car_csv = pd.read_csv('./dataset/cars.csv', index_col=0)

# %%
car_csv
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JPN           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
car = car_csv[['country', 'drives_right']]

# %%
filtered_car = car[0:4]
filtered_car
# Out:
#            country  drives_right
# US   United States          True
# AUS      Australia         False
# JPN          Japan         False
# IN           India         False

# %%
filtered_car.loc[['US', 'AUS']]
# Out:
#            country  drives_right
# US   United States          True
# AUS      Australia         False

# %%
filtered_car.iloc[0:2,0:2] # When doing slicing there's no need to add extra brackets
# Out:
#            country  drives_right
# US   United States          True
# AUS      Australia         False

# %%
import numpy as np

# %%
titanic = pd.read_csv(r'C:\Users\USER\SMIT\CDE\cde-b3-smit\Python\class-18-10-25\dataset\titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(titanic.values)
# Out:
# [[1 0 3 ... 7.25 nan 'S']
#  [2 1 1 ... 71.2833 'C85' 'C']
#  [3 1 3 ... 7.925 nan 'S']
#  ...
#  [889 0 3 ... 23.45 nan 'S']
#  [890 1 1 ... 30.0 'C148' 'C']
#  [891 0 3 ... 7.75 nan 'Q']]

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.sort_values(by='Age', ascending=False, na_position='first')
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 5              6         0       3                 Moran, Mr. James    male
# 17            18         1       2     Williams, Mr. Charles Eugene    male
# 19            20         1       3          Masselmani, Mrs. Fatima  female
# 26            27         0       3          Emir, Mr. Farred Chehab    male
# 28            29         1       3    O'Dwyer, Miss. Ellen "Nellie"  female
# ..           ...       ...     ...                              ...     ...
# 831          832         1       2  Richards, Master. George Sibley    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 803          804         1       3  Thomas, Master. Assad Alexander    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.dropna(subset=['Age'], inplace=True)

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          529
# Embarked         2
# dtype: int64

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[["Name","Survived"]]
# Out:
#                                                   Name  Survived
# 0                              Braund, Mr. Owen Harris         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                               Heikkinen, Miss. Laina         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4                             Allen, Mr. William Henry         0
# ..                                                 ...       ...
# 885               Rice, Mrs. William (Margaret Norton)         0
# 886                              Montvila, Rev. Juozas         0
# 887                       Graham, Miss. Margaret Edith         1
# 889                              Behr, Mr. Karl Howell         1
# 890                                Dooley, Mr. Patrick         0
#
# [714 rows x 2 columns]

# %%
titanic[titanic['Age'] >30 ]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[titanic['Sex'] == 'male' ]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
sex_male = titanic['Sex'] == 'male'
not_survived = titanic['Survived'] == 0
# titanic[sex_male & not_survived].count()
titanic[sex_male & not_survived]
# Out:
# PassengerId    360
# Survived       360
# Pclass         360
# Name           360
# Sex            360
# Age            360
# SibSp          360
# Parch          360
# Ticket         360
# Fare           360
# Cabin           54
# Embarked       360
# dtype: int64

# %%
sex_female = titanic['Sex'] == 'female'
age_less_20 = titanic['Age'] < 20
survived = titanic['Survived'] == 1
# titanic[sex_female & survived & age_less_20].count()
titanic[sex_female & survived & age_less_20]
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 10            11         1       3
# 22            23         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 58            59         1       2
# 68            69         1       3
# 84            85         1       2
# 136          137         1       1
# 156          157         1       3
# 172          173         1       3
# 184          185         1       3
# 192          193         1       3
# 208          209         1       3
# 233          234         1       3
# 237          238         1       2
# 291          292         1       1
# 307          308         1       1
# 311          312         1       1
# 329          330         1       1
# 381          382         1       3
# 389          390         1       2
# 417          418         1       2
# 427          428         1       2
# ...

# %%
titanic['Discounted_fare'] = (titanic['Fare']/100) * 25

# %%
titanic['Discounted_fare']
# Out:
# 0       1.812500
# 1      17.820825
# 2       1.981250
# 3      13.275000
# 4       2.012500
#          ...
# 885     7.281250
# 886     3.250000
# 887     7.500000
# 889     7.500000
# 890     1.937500
# Name: Discounted_fare, Length: 714, dtype: float64

# %%
Age_It_20 = titanic[titanic['Age']<20]
descending_order = Age_It_20.sort_values('Age', ascending=False)
descending_order[['Name', 'Age', 'Sex']]
# Out:
#                                 Name    Age     Sex
# 136     Newsom, Miss. Helen Monypeny  19.00  female
# 67          Crease, Mr. Ernest James  19.00    male
# 44     Devaney, Miss. Margaret Delia  19.00  female
# 27    Fortune, Mr. Charles Alexander  19.00    male
# 143              Burke, Mr. Jeremiah  19.00    male
# ..                               ...    ...     ...
# 831  Richards, Master. George Sibley   0.83    male
# 469    Baclini, Miss. Helene Barbara   0.75  female
# 644           Baclini, Miss. Eugenie   0.75  female
# 755        Hamalainen, Master. Viljo   0.67    male
# 803  Thomas, Master. Assad Alexander   0.42    male
#
# [164 rows x 3 columns]
