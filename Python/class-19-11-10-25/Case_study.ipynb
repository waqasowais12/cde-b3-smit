# %% [markdown]
# ## CASE STUDY DATA VISUALIZATION (gapminder)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./gapminder.csv')
df
# Out:
#      Unnamed: 0             country  year  population      cont  life_exp  \
# 0            11         Afghanistan  2007  31889923.0      Asia    43.828
# 1            23             Albania  2007   3600523.0    Europe    76.423
# 2            35             Algeria  2007  33333216.0    Africa    72.301
# 3            47              Angola  2007  12420476.0    Africa    42.731
# 4            59           Argentina  2007  40301927.0  Americas    75.320
# ..          ...                 ...   ...         ...       ...       ...
# 137        1655             Vietnam  2007  85262356.0      Asia    74.249
# 138        1667  West Bank and Gaza  2007   4018332.0      Asia    73.422
# 139        1679         Yemen, Rep.  2007  22211743.0      Asia    62.698
# 140        1691              Zambia  2007  11746035.0    Africa    42.384
# 141        1703            Zimbabwe  2007  12311143.0    Africa    43.487
#
#           gdp_cap
# 0      974.580338
# 1     5937.029526
# 2     6223.367465
# 3     4797.231267
# 4    12779.379640
# ..            ...
# 137   2441.576404
# 138   3025.349798
# 139   2280.769906
# 140   1271.211593
# 141    469.709298
#
# [142 rows x 7 columns]

# %%
df.head(10)
# Out:
#    Unnamed: 0      country  year   population      cont  life_exp  \
# 0          11  Afghanistan  2007   31889923.0      Asia    43.828
# 1          23      Albania  2007    3600523.0    Europe    76.423
# 2          35      Algeria  2007   33333216.0    Africa    72.301
# 3          47       Angola  2007   12420476.0    Africa    42.731
# 4          59    Argentina  2007   40301927.0  Americas    75.320
# 5          71    Australia  2007   20434176.0   Oceania    81.235
# 6          83      Austria  2007    8199783.0    Europe    79.829
# 7          95      Bahrain  2007     708573.0      Asia    75.635
# 8         107   Bangladesh  2007  150448339.0      Asia    64.062
# 9         119      Belgium  2007   10392226.0    Europe    79.441
#
#         gdp_cap
# 0    974.580338
# 1   5937.029526
# 2   6223.367465
# 3   4797.231267
# 4  12779.379640
# 5  34435.367440
# 6  36126.492700
# 7  29796.048340
# 8   1391.253792
# 9  33692.605080

# %%
len(df)
# Out:
# 142

# %%
life_exp = df['life_exp']
gdp_cap = df['gdp_cap']

plt.scatter(gdp_cap, life_exp)
# plt.xscale('log')

xlabel = 'GDP per capita [in USD]'
ylabel = 'life Expentancy[in Year]'
title = 'World Developemnt in 2007'

plt.title(title)
plt.xlabel(xlabel)
plt.ylabel(ylabel)

plt.show()

# %%
plt.scatter(gdp_cap, life_exp)

plt.xscale('log')
plt.xlabel('GDP per capita [in USD]')
plt.ylabel('Life Expectancy [in Year]')
plt.title('World Development in 2007')

tick_val = [1000, 10000, 100000]
tick_lab = ['1k', '10k', '100k']

plt.xticks(tick_val, tick_lab)


plt.show()

# %%
pop = [31.889923, 3.600523, 33.333216, 12.420476, 40.301927, 20.434176, 8.199783, 0.708573, 150.448339, 10.392226, 8.078314, 9.119152, 4.552198, 1.639131, 190.010647, 7.322858, 14.326203, 8.390505, 14.131858, 17.696293, 33.390141, 4.369038, 10.238807, 16.284741, 1318.683096, 44.22755, 0.71096, 64.606759, 3.80061, 4.133884, 18.013409, 4.493312, 11.416987, 
col = ['red', 'green', 'blue', 'blue', 'yellow', 'black', 'green', 'red', 'red', 'green', 'blue', 'yellow', 'green', 'blue', 'yellow', 'green', 'blue', 'blue', 'red', 'blue', 'yellow', 'blue', 'blue', 'yellow', 'red', 'yellow', 'blue', 'blue', 'blue', 'yellow', 'blue', 'green', 'yellow', 'green', 'green', 'blue', 'yellow', 'yellow', 'blue', 'yellow', 'blue', 'blue', 'blue', 'green', 'green', 'blue', 'blue', 'green', 'blue', 'green', 'yellow', 'blue', 'blue', 'yellow', 'yellow', 'red', 'green', 'green', 'red', 'red', 'red', 'red', 'green', 'red', 'green', 'yellow', 'red', 'red', 'blue', 'red', 'red', 'red', 'red', 'blue', 'blue', 'blue', 'blue', 'blue', 'red', 'blue', 'blue', 'blue', 'yellow', 'red', 'green', 'blue', 'blue', 'red', 'blue', 'red', 'green', 'black', 'yellow', 'blue', 'blue', 'green', 'red', 'red', 'yellow', 'yellow', 'yellow', 'red', 'green', 'green', 'yellow', 'blue', 'green', 'blue', 'blue', 'red', 'blue', 'green', 'blue', 'red', 'green', 'green', 'blue', 'blue', 'green', 'red', 'blue', 'blue', 'green', 'green', 'red', 'red', 'blue', 'red', 'blue', 'yellow', 'blue', 'green', 'blue', 'green', 'yellow', 'yellow', 'yellow', 'red', 'red', 'red', 'blue', 'blue']

np_pop = np.array(pop)

np_pop = np_pop*2

plt.scatter(gdp_cap, life_exp, s=np_pop, c=col)
plt.xscale('log')
plt.xlabel('GDP per capita [in USD]')
plt.ylabel('Life Expectancy [in Year]')
plt.title('World Development in 2007')
plt.xticks([1000,10000,100000,],['1k','10k','100k'])

plt.show()

# %% [markdown]
# ### ADDING GRID

# %%
plt.scatter(gdp_cap, life_exp, s=np_pop, c=col, alpha=0.8)

plt.xscale('log')


plt.xlabel('GDP per capita [in USD]')
plt.ylabel('Life Expectancy [in Year]')
plt.title('World Development in 2007')
plt.text(2500,65, 'India')
plt.text(5000,78, 'China')

plt.xticks([1000,10000,100000,],['1k','10k','100k'])
plt.grid(True)

plt.show()

# %% [markdown]
# ## TASK

# %%
data = {
    'Country': ['USA', 'China', 'India', 'Germany', 'Brazil', 'Japan', 'Russia', 'Canada', 'Australia', 'Mexico'],
    'GDP per Capita (USD)': [59850, 10660, 1800, 46100, 10600, 38900, 10750, 41300, 51000, 9500],
    'Life Expectancy (years)': [78.54, 76.91, 69.42, 81.13, 75.88, 84.6, 73.34, 82.2, 82.5, 77.03],
    'Population (millions)': [331, 1393, 1380, 83, 213, 126, 145, 38, 26, 128],
    'Color Grading': [59850, 10660, 1800, 46100, 10600, 38900, 10750, 41300, 51000, 9500]  # Using GDP for color
}

df = pd.DataFrame(data)
len(df)
# Out:
# 10

# %%
life_exp = df['Life Expectancy (years)']
gdp_cap = df['GDP per Capita (USD)']

plt.scatter(gdp_cap, life_exp)

# plt.xscale('log')
plt.xlabel('GDP per capita [in USD]')
plt.ylabel('Life Expectancy [in Year]')
plt.title('World Development in 2007')
plt.show()

# %%
life_exp = df['Life Expectancy (years)']
gdp_cap = df['GDP per Capita (USD)']

plt.scatter(gdp_cap, life_exp)

plt.xscale('log')
plt.xlabel('GDP per capita [in USD]')
plt.ylabel('Life Expectancy [in Year]')
plt.title('World Development in 2007')
plt.show()

# %%
life_exp = df['Life Expectancy (years)']
gdp_cap = df['GDP per Capita (USD)']

plt.scatter(gdp_cap, life_exp)

# plt.xscale('log')
plt.xlabel('GDP per capita [in USD]')
plt.ylabel('Life Expectancy [in Year]')
plt.title('World Development in 2007')


plt.xticks([1000,10000,20000,30000,40000,50000,60000],['1k','10k','20k','30k','40k','50k','60k'])
plt.show()

# %%
pop = [31.889923, 3.600523, 33.333216, 12.420476, 40.301927, 20.434176, 8.199783, 0.708573, 150.448339, 10.392226]

# print(len(pop))

col = ['red', 'green', 'blue', 'blue', 'yellow', 'black', 'green', 'red', 'red', 'green']
np_pop = np.array(pop)
np_pop = np_pop*10

plt.scatter(gdp_cap, life_exp, s=np_pop, c=col, alpha=0.8)
# plt.xscale('log')
plt.xlabel('GDP per capita [in USD]')
plt.ylabel('Life Expectancy [in Year]')
plt.title('World Development in 2007')
plt.grid()

plt.xticks([1000,10000,20000,30000,40000,50000,60000],['1k','10k','20k','30k','40k','50k','60k'])
plt.show()

# %%
# data = {
#     'Country': ['USA', 'China', 'India', 'Germany', 'Brazil', 'Japan', 'Russia', 'Canada', 'Australia', 'Mexico'],
#     'GDP per Capita (USD)': [59850, 10660, 1800, 46100, 10600, 38900, 10750, 41300, 51000, 9500],
#     'Life Expectancy (years)': [78.54, 76.91, 69.42, 81.13, 75.88, 84.6, 73.34, 82.2, 82.5, 77.03],
#     'Population (millions)': [331, 1393, 1380, 83, 213, 126, 145, 38, 26, 128],
#     'Color Grading': [59850, 10660, 1800, 46100, 10600, 38900, 10750, 41300, 51000, 9500]  # Using GDP for color
# }
pop = [31.889923, 3.600523, 33.333216, 12.420476, 40.301927, 20.434176, 8.199783, 0.708573, 150.448339, 10.392226]

# print(len(pop))

col = ['cyan', 'magenta', 'lime', 'teal', 'navy', 'maroon', 'olive', 'gold', 'silver', 'beige']

np_pop = np.array(pop)
np_pop = np_pop*50

plt.scatter(gdp_cap, life_exp, s=np_pop, c=col, alpha=0.8)

# plt.xscale('log')
# plt.figure(figsize=(9, 7))
plt.xlabel('GDP per capita [in USD]')
plt.ylabel('Life Expectancy [in Year]')
plt.title('World Development in 2007')
plt.text(59850,78.54,'USA')
plt.text(10660,76.91,'China')
plt.text(1800,69.42,'India')
plt.text(46100,81.13,'Germany')
plt.text(10600,75.88,'Brazil')
plt.text(38900,84.6,'Japan')
plt.text(10750,73.34,'Russia')
plt.text(41300,82.2,'Canada')
plt.text(51000,82.5,'Australia')
plt.text(9500,77.03,'Mexico')
plt.grid()

plt.xticks([1000,10000,20000,30000,40000,50000,60000],['1k','10k','20k','30k','40k','50k','60k'])
plt.show()
