# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ![join](./img/joins.png)

# %% [markdown]
# ## 1. Inner Join
#
# ![innerJoin.png](img/inner_join.png)

# %%
left_table = {'Date': ['01-01-2020', '02-01-2020', '03-01-2020', '04-01-2020' ],
              'CountryID': [1,1,3,2],
              'Units': [40, 25, 30, 35]}

# %%
left_table_df = pd.DataFrame(left_table)
left_table_df
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 2  03-01-2020          3     30
# 3  04-01-2020          2     35

# %%
right_table = {'CountryID': [3,4],
              'Country': ['Pandama', 'Spain']}

# %%
right_table_df = pd.DataFrame(right_table)
right_table_df
# Out:
#    CountryID  Country
# 0          3  Pandama
# 1          4    Spain

# %%
inner_join = left_table_df.merge(right_table_df, on='CountryID') # by default merge function works as inner join
inner_join
# Out:
#          Date  CountryID  Units  Country
# 0  03-01-2020          3     30  Pandama

# %%
right_table = {'ID': [3,4],
              'Country': ['Pandama', 'Spain']}

# %%
right_table_df = pd.DataFrame(right_table)
right_table_df
# Out:
#    ID  Country
# 0   3  Pandama
# 1   4    Spain

# %%
left_table_df
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 2  03-01-2020          3     30
# 3  04-01-2020          2     35

# %%
inner_join = left_table_df.merge(right_table_df, left_on='CountryID', right_on='ID')
inner_join
# Out:
#          Date  CountryID  Units  ID  Country
# 0  03-01-2020          3     30   3  Pandama

# %%
inner_join = left_table_df.merge(right_table_df, left_on='CountryID', right_on='ID').drop('ID',axis=1)
inner_join
# Out:
#          Date  CountryID  Units  Country
# 0  03-01-2020          3     30  Pandama

# %%
left_table['Country'] = ['PAK', 'IND', 'IRAN', 'USA']

# %%
left_table_df = pd.DataFrame(left_table)
left_table_df
# Out:
#          Date  CountryID  Units Country
# 0  01-01-2020          1     40     PAK
# 1  02-01-2020          1     25     IND
# 2  03-01-2020          3     30    IRAN
# 3  04-01-2020          2     35     USA

# %%
inner_join = left_table_df.merge(right_table_df, left_on='CountryID', right_on='ID', suffixes=['_left', '_right']).drop('ID',axis=1)
inner_join
# Out:
#          Date  CountryID  Units Country_left Country_right
# 0  03-01-2020          3     30         IRAN       Pandama

# %% [markdown]
# ## 2. LEFT JOIN
#
# ![left-join.png](img/left_join.png)

# %%
left_table = {'Date': ['01-01-2020', '02-01-2020', '03-01-2020', '04-01-2020' ],
              'CountryID': [1,1,3,2],
              'Units': [40, 25, 30, 35]}

left_table_df = pd.DataFrame(left_table)
left_table_df
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 2  03-01-2020          3     30
# 3  04-01-2020          2     35

# %%
right_table = {'ID': [3,4],
              'Country': ['Pandama', 'Spain']}

right_table_df = pd.DataFrame(right_table)
right_table_df
# Out:
#    ID  Country
# 0   3  Pandama
# 1   4    Spain

# %%
left_join = left_table_df.merge(right_table_df, left_on='CountryID', right_on='ID', how='left').drop('ID', axis=1)
left_join
# Out:
#          Date  CountryID  Units  Country
# 0  01-01-2020          1     40      NaN
# 1  02-01-2020          1     25      NaN
# 2  03-01-2020          3     30  Pandama
# 3  04-01-2020          2     35      NaN

# %%
right_table = {'ID': [3,4],
              'Country': ['Pandama', 'Spain']}

right_table_df = pd.DataFrame(right_table)
right_table_df
# Out:
#    ID  Country
# 0   3  Pandama
# 1   4    Spain

# %%
full_outer_join = left_table_df.merge(right_table_df, left_on='CountryID', right_on='ID', how='outer')
full_outer_join
# Out:
#          Date  CountryID  Units   ID  Country
# 0  01-01-2020        1.0   40.0  NaN      NaN
# 1  02-01-2020        1.0   25.0  NaN      NaN
# 2  04-01-2020        2.0   35.0  NaN      NaN
# 3  03-01-2020        3.0   30.0  3.0  Pandama
# 4         NaN        NaN    NaN  4.0    Spain

# %% [markdown]
# ## 3. RIGHT JOIN
#
# ![right-join.png](img/right_join.png)

# %%
left_table = {'Date': ['01-01-2020', '02-01-2020', '03-01-2020', '04-01-2020' ],
              'CountryID': [1,1,3,2],
              'Units': [40, 25, 30, 35]}

left_table_df = pd.DataFrame(left_table)
left_table_df
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 2  03-01-2020          3     30
# 3  04-01-2020          2     35

# %%
right_table = {'ID': [3,4],
              'Country': ['Pandama', 'Spain']}

right_table_df = pd.DataFrame(right_table)
right_table_df
# Out:
#    ID  Country
# 0   3  Pandama
# 1   4    Spain

# %%
right_join = left_table_df.merge(right_table_df, left_on='CountryID', right_on='ID', how='right')
right_join
# Out:
#          Date  CountryID  Units  ID  Country
# 0  03-01-2020        3.0   30.0   3  Pandama
# 1         NaN        NaN    NaN   4    Spain

# %% [markdown]
# ## 4. FULL OUTER JOIN
#
# ![fullterOuter-join.png](img/full_outer_join.png)

# %%
left_table = {'Date': ['01-01-2020', '02-01-2020', '03-01-2020', '04-01-2020' ],
              'CountryID': [1,1,3,2],
              'Units': [40, 25, 30, 35]}

left_table_df = pd.DataFrame(left_table)
left_table_df
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 2  03-01-2020          3     30
# 3  04-01-2020          2     35

# %% [markdown]
# ## 5. LEFT ANTI
#
# ![leftAnti-join.png](img/left_anti_join.png)

# %%
left_table = {'Date': ['01-01-2020', '02-01-2020', '03-01-2020', '04-01-2020' ],
              'CountryID': [1,1,3,2],
              'Units': [40, 25, 30, 35]}

# %%
left_table_df = pd.DataFrame(left_table)
left_table_df
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 2  03-01-2020          3     30
# 3  04-01-2020          2     35

# %%
right_table = {'ID': [3,4],
              'Country': ['Pandama', 'Spain']}

# %%
right_table_df = pd.DataFrame(right_table)
right_table_df
# Out:
#    ID  Country
# 0   3  Pandama
# 1   4    Spain

# %%
left_table_df
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 2  03-01-2020          3     30
# 3  04-01-2020          2     35

# %%
right_table_df
# Out:
#    ID  Country
# 0   3  Pandama
# 1   4    Spain

# %%
left_anti = left_table_df.merge(right_table_df, left_on='CountryID', right_on='ID', how='left')
left_anti
# Out:
#          Date  CountryID  Units   ID  Country
# 0  01-01-2020          1     40  NaN      NaN
# 1  02-01-2020          1     25  NaN      NaN
# 2  03-01-2020          3     30  3.0  Pandama
# 3  04-01-2020          2     35  NaN      NaN

# %%
# method 1
left_anti = left_table_df.merge(right_table_df, left_on='CountryID', right_on='ID', how='left')
left_anti[left_anti['Country'].isna()][['Date', 'CountryID', 'Units']]
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 3  04-01-2020          2     35

# %%
# method 2
left_join_df = left_table_df.merge(right_table_df,
                                   left_on="CountryID",
                                   right_on='ID',
                                   how='left', indicator=True).drop('ID', axis=1)
left_join_df
# Out:
#          Date  CountryID  Units  Country     _merge
# 0  01-01-2020          1     40      NaN  left_only
# 1  02-01-2020          1     25      NaN  left_only
# 2  03-01-2020          3     30  Pandama       both
# 3  04-01-2020          2     35      NaN  left_only

# %%
left_join_df.loc[left_join_df['_merge'] == 'left_only']
# Out:
#          Date  CountryID  Units Country     _merge
# 0  01-01-2020          1     40     NaN  left_only
# 1  02-01-2020          1     25     NaN  left_only
# 3  04-01-2020          2     35     NaN  left_only

# %% [markdown]
# ### 6. RIGHT ANTI
#
# ![rightAnti-join.png](img/right_anti_join.png)

# %%
left_table = {'Date': ['01-01-2020', '02-01-2020', '03-01-2020', '04-01-2020' ],
              'CountryID': [1,1,3,2],
              'Units': [40, 25, 30, 35]}
left_table_df = pd.DataFrame(left_table)
left_table_df
# Out:
#          Date  CountryID  Units
# 0  01-01-2020          1     40
# 1  02-01-2020          1     25
# 2  03-01-2020          3     30
# 3  04-01-2020          2     35

# %%
right_table = {'ID': [3,4],
              'Country': ['Pandama', 'Spain']}
right_table_df = pd.DataFrame(right_table)
right_table_df
# Out:
#    ID  Country
# 0   3  Pandama
# 1   4    Spain

# %%
right_anti = left_table_df.merge(right_table_df, left_on='CountryID', right_on='ID', how='right')
right_anti
# Out:
#          Date  CountryID  Units  ID  Country
# 0  03-01-2020        3.0   30.0   3  Pandama
# 1         NaN        NaN    NaN   4    Spain

# %%
# method 1
right_anti[right_anti['CountryID'].isna()][['Date', 'CountryID', 'Units','Country']]
# Out:
#   Date  CountryID  Units Country
# 1  NaN        NaN    NaN   Spain

# %%
# method 2
right_anti = left_table_df.merge(right_table_df, left_on='CountryID', right_on='ID', how='right', indicator=True)
right_anti
# Out:
#          Date  CountryID  Units  ID  Country      _merge
# 0  03-01-2020        3.0   30.0   3  Pandama        both
# 1         NaN        NaN    NaN   4    Spain  right_only

# %%
right_anti.loc[right_anti['_merge'] == 'right_only']
# Out:
#   Date  CountryID  Units  ID Country      _merge
# 1  NaN        NaN    NaN   4   Spain  right_only

# %%
right_anti.loc[right_anti['_merge'] == 'right_only'].drop(['_merge', 'ID'], axis=1)
# Out:
#   Date  CountryID  Units Country
# 1  NaN        NaN    NaN   Spain

# %% [markdown]
# ### TASK

# %%
employees = {
    'Emp_ID': range(1001, 1021),
    'Name': [
        'Ali', 'Sara', 'Umer', 'Hina', 'Bilal', 'Ayesha', 'Raza', 'Mona', 'Danish', 'Tuba',
        'Kashif', 'Iqra', 'Ahmed', 'Nida', 'Owais', 'Farah', 'Zain', 'Mehak', 'Haris', 'Amna'
    ],
    'Dept_ID': [101,102,103,104,105,101,102,103,104,105,101,102,103,104,105,101,102,103,104,105],
    'Salary': [
        70000, 82000, 60000, 90000, 75000, 71000, 88000, 64000, 94000, 77000,
        73000, 85000, 62000, 91000, 76000, 70500, 89500, 65000, 93000, 78000
    ],
    'Join_Year': [
        2018,2019,2020,2018,2017,2019,2018,2021,2022,2020,
        2017,2018,2019,2021,2022,2023,2019,2020,2021,2022
    ]
}

emp_df = pd.DataFrame(employees)
emp_df
# Out:
#     Emp_ID    Name  Dept_ID  Salary  Join_Year
# 0     1001     Ali      101   70000       2018
# 1     1002    Sara      102   82000       2019
# 2     1003    Umer      103   60000       2020
# 3     1004    Hina      104   90000       2018
# 4     1005   Bilal      105   75000       2017
# 5     1006  Ayesha      101   71000       2019
# 6     1007    Raza      102   88000       2018
# 7     1008    Mona      103   64000       2021
# 8     1009  Danish      104   94000       2022
# 9     1010    Tuba      105   77000       2020
# 10    1011  Kashif      101   73000       2017
# 11    1012    Iqra      102   85000       2018
# 12    1013   Ahmed      103   62000       2019
# 13    1014    Nida      104   91000       2021
# 14    1015   Owais      105   76000       2022
# 15    1016   Farah      101   70500       2023
# 16    1017    Zain      102   89500       2019
# 17    1018   Mehak      103   65000       2020
# 18    1019   Haris      104   93000       2021
# 19    1020    Amna      105   78000       2022

# %%
departments = {
    'Dept_ID': [101,102,103,104,105,106],
    'Dept_Name': ['HR','IT','Finance','Marketing','Sales','Operations'],
    'Manager': ['Faisal','Asma','Kamran','Tariq','Sadia','Hassan'],
    'Location': ['Lahore','Karachi','Islamabad','Lahore','Karachi','Faisalabad']
}

dep_df = pd.DataFrame(departments)
dep_df
# Out:
#    Dept_ID   Dept_Name Manager    Location
# 0      101          HR  Faisal      Lahore
# 1      102          IT    Asma     Karachi
# 2      103     Finance  Kamran   Islamabad
# 3      104   Marketing   Tariq      Lahore
# 4      105       Sales   Sadia     Karachi
# 5      106  Operations  Hassan  Faisalabad

# %% [markdown]
# ## 1. INNER JOIN

# %%
inner_join = emp_df.merge(dep_df, left_on='Dept_ID', right_on='Dept_ID')
inner_join
# Out:
#     Emp_ID    Name  Dept_ID  Salary  Join_Year  Dept_Name Manager   Location
# 0     1001     Ali      101   70000       2018         HR  Faisal     Lahore
# 1     1002    Sara      102   82000       2019         IT    Asma    Karachi
# 2     1003    Umer      103   60000       2020    Finance  Kamran  Islamabad
# 3     1004    Hina      104   90000       2018  Marketing   Tariq     Lahore
# 4     1005   Bilal      105   75000       2017      Sales   Sadia    Karachi
# 5     1006  Ayesha      101   71000       2019         HR  Faisal     Lahore
# 6     1007    Raza      102   88000       2018         IT    Asma    Karachi
# 7     1008    Mona      103   64000       2021    Finance  Kamran  Islamabad
# 8     1009  Danish      104   94000       2022  Marketing   Tariq     Lahore
# 9     1010    Tuba      105   77000       2020      Sales   Sadia    Karachi
# 10    1011  Kashif      101   73000       2017         HR  Faisal     Lahore
# 11    1012    Iqra      102   85000       2018         IT    Asma    Karachi
# 12    1013   Ahmed      103   62000       2019    Finance  Kamran  Islamabad
# 13    1014    Nida      104   91000       2021  Marketing   Tariq     Lahore
# 14    1015   Owais      105   76000       2022      Sales   Sadia    Karachi
# 15    1016   Farah      101   70500       2023         HR  Faisal     Lahore
# 16    1017    Zain      102   89500       2019         IT    Asma    Karachi
# 17    1018   Mehak      103   65000       2020    Finance  Kamran  Islamabad
# 18    1019   Haris      104   93000       2021  Marketing   Tariq     Lahore
# 19    1020    Amna      105   78000       2022      Sales   Sadia    Karachi

# %% [markdown]
# ## 2. LEFT JOIN

# %%
left_join = emp_df.merge(dep_df, left_on='Dept_ID', right_on='Dept_ID', how='left')
left_join
# Out:
#     Emp_ID    Name  Dept_ID  Salary  Join_Year  Dept_Name Manager   Location
# 0     1001     Ali      101   70000       2018         HR  Faisal     Lahore
# 1     1002    Sara      102   82000       2019         IT    Asma    Karachi
# 2     1003    Umer      103   60000       2020    Finance  Kamran  Islamabad
# 3     1004    Hina      104   90000       2018  Marketing   Tariq     Lahore
# 4     1005   Bilal      105   75000       2017      Sales   Sadia    Karachi
# 5     1006  Ayesha      101   71000       2019         HR  Faisal     Lahore
# 6     1007    Raza      102   88000       2018         IT    Asma    Karachi
# 7     1008    Mona      103   64000       2021    Finance  Kamran  Islamabad
# 8     1009  Danish      104   94000       2022  Marketing   Tariq     Lahore
# 9     1010    Tuba      105   77000       2020      Sales   Sadia    Karachi
# 10    1011  Kashif      101   73000       2017         HR  Faisal     Lahore
# 11    1012    Iqra      102   85000       2018         IT    Asma    Karachi
# 12    1013   Ahmed      103   62000       2019    Finance  Kamran  Islamabad
# 13    1014    Nida      104   91000       2021  Marketing   Tariq     Lahore
# 14    1015   Owais      105   76000       2022      Sales   Sadia    Karachi
# 15    1016   Farah      101   70500       2023         HR  Faisal     Lahore
# 16    1017    Zain      102   89500       2019         IT    Asma    Karachi
# 17    1018   Mehak      103   65000       2020    Finance  Kamran  Islamabad
# 18    1019   Haris      104   93000       2021  Marketing   Tariq     Lahore
# 19    1020    Amna      105   78000       2022      Sales   Sadia    Karachi

# %% [markdown]
# ## 3. RIGHT JOIN

# %%
right_join = emp_df.merge(dep_df, left_on='Dept_ID', right_on='Dept_ID', how='right')
right_join
# Out:
#     Emp_ID    Name  Dept_ID   Salary  Join_Year   Dept_Name Manager  \
# 0   1001.0     Ali      101  70000.0     2018.0          HR  Faisal
# 1   1006.0  Ayesha      101  71000.0     2019.0          HR  Faisal
# 2   1011.0  Kashif      101  73000.0     2017.0          HR  Faisal
# 3   1016.0   Farah      101  70500.0     2023.0          HR  Faisal
# 4   1002.0    Sara      102  82000.0     2019.0          IT    Asma
# 5   1007.0    Raza      102  88000.0     2018.0          IT    Asma
# 6   1012.0    Iqra      102  85000.0     2018.0          IT    Asma
# 7   1017.0    Zain      102  89500.0     2019.0          IT    Asma
# 8   1003.0    Umer      103  60000.0     2020.0     Finance  Kamran
# 9   1008.0    Mona      103  64000.0     2021.0     Finance  Kamran
# 10  1013.0   Ahmed      103  62000.0     2019.0     Finance  Kamran
# 11  1018.0   Mehak      103  65000.0     2020.0     Finance  Kamran
# 12  1004.0    Hina      104  90000.0     2018.0   Marketing   Tariq
# 13  1009.0  Danish      104  94000.0     2022.0   Marketing   Tariq
# 14  1014.0    Nida      104  91000.0     2021.0   Marketing   Tariq
# 15  1019.0   Haris      104  93000.0     2021.0   Marketing   Tariq
# 16  1005.0   Bilal      105  75000.0     2017.0       Sales   Sadia
# 17  1010.0    Tuba      105  77000.0     2020.0       Sales   Sadia
# 18  1015.0   Owais      105  76000.0     2022.0       Sales   Sadia
# 19  1020.0    Amna      105  78000.0     2022.0       Sales   Sadia
# 20     NaN     NaN      106      NaN        NaN  Operations  Hassan
#
#       Location
# 0       Lahore
# 1       Lahore
# 2       Lahore
# 3       Lahore
# 4      Karachi
# 5      Karachi
# 6      Karachi
# 7      Karachi
# 8    Islamabad
# 9    Islamabad
# 10   Islamabad
# 11   Islamabad
# 12      Lahore
# 13      Lahore
# 14      Lahore
# 15      Lahore
# 16     Karachi
# 17     Karachi
# 18     Karachi
# 19     Karachi
# 20  Faisalabad

# %% [markdown]
# ## 4. FULL OUTER JOIN

# %%
full_outer_join = emp_df.merge(dep_df, left_on='Dept_ID', right_on='Dept_ID', how='outer')
full_outer_join
# Out:
#     Emp_ID    Name  Dept_ID   Salary  Join_Year   Dept_Name Manager  \
# 0   1001.0     Ali      101  70000.0     2018.0          HR  Faisal
# 1   1006.0  Ayesha      101  71000.0     2019.0          HR  Faisal
# 2   1011.0  Kashif      101  73000.0     2017.0          HR  Faisal
# 3   1016.0   Farah      101  70500.0     2023.0          HR  Faisal
# 4   1002.0    Sara      102  82000.0     2019.0          IT    Asma
# 5   1007.0    Raza      102  88000.0     2018.0          IT    Asma
# 6   1012.0    Iqra      102  85000.0     2018.0          IT    Asma
# 7   1017.0    Zain      102  89500.0     2019.0          IT    Asma
# 8   1003.0    Umer      103  60000.0     2020.0     Finance  Kamran
# 9   1008.0    Mona      103  64000.0     2021.0     Finance  Kamran
# 10  1013.0   Ahmed      103  62000.0     2019.0     Finance  Kamran
# 11  1018.0   Mehak      103  65000.0     2020.0     Finance  Kamran
# 12  1004.0    Hina      104  90000.0     2018.0   Marketing   Tariq
# 13  1009.0  Danish      104  94000.0     2022.0   Marketing   Tariq
# 14  1014.0    Nida      104  91000.0     2021.0   Marketing   Tariq
# 15  1019.0   Haris      104  93000.0     2021.0   Marketing   Tariq
# 16  1005.0   Bilal      105  75000.0     2017.0       Sales   Sadia
# 17  1010.0    Tuba      105  77000.0     2020.0       Sales   Sadia
# 18  1015.0   Owais      105  76000.0     2022.0       Sales   Sadia
# 19  1020.0    Amna      105  78000.0     2022.0       Sales   Sadia
# 20     NaN     NaN      106      NaN        NaN  Operations  Hassan
#
#       Location
# 0       Lahore
# 1       Lahore
# 2       Lahore
# 3       Lahore
# 4      Karachi
# 5      Karachi
# 6      Karachi
# 7      Karachi
# 8    Islamabad
# 9    Islamabad
# 10   Islamabad
# 11   Islamabad
# 12      Lahore
# 13      Lahore
# 14      Lahore
# 15      Lahore
# 16     Karachi
# 17     Karachi
# 18     Karachi
# 19     Karachi
# 20  Faisalabad

# %% [markdown]
# ## 5. LEFT ANTI JOIN

# %%
left_anti_join = emp_df.merge(dep_df, left_on='Dept_ID', right_on='Dept_ID', how='left')
left_anti_join[left_anti_join['Dept_ID'].isna()][['Emp_ID', 'Name', 'Dept_ID',	'Salary', 'Join_Year', 'Dept_Name', 'Manager', 'Location']]
# Out:
# Empty DataFrame
# Columns: [Emp_ID, Name, Dept_ID, Salary, Join_Year, Dept_Name, Manager, Location]
# Index: []

# %%
left_anti_join = emp_df.merge(dep_df, left_on='Dept_ID', right_on='Dept_ID', how='left', indicator=True)
left_anti_join[left_anti_join['_merge'] == 'left_only']
# Out:
# Empty DataFrame
# Columns: [Emp_ID, Name, Dept_ID, Salary, Join_Year, Dept_Name, Manager, Location, _merge]
# Index: []

# %% [markdown]
# ## 6. RIGHT ANTI

# %%
right_anti_join = emp_df.merge(dep_df, left_on='Dept_ID', right_on='Dept_ID', indicator=True)
right_anti_join[right_anti_join['_merge'] == 'right_only']
# Out:
# Empty DataFrame
# Columns: [Emp_ID, Name, Dept_ID, Salary, Join_Year, Dept_Name, Manager, Location, _merge]
# Index: []

# %%
right_anti_join = emp_df.merge(dep_df, left_on='Dept_ID', right_on='Dept_ID', how='right')
right_anti_join[right_anti_join['Dept_ID'].isna()]
# Out:
# Empty DataFrame
# Columns: [Emp_ID, Name, Dept_ID, Salary, Join_Year, Dept_Name, Manager, Location]
# Index: []
